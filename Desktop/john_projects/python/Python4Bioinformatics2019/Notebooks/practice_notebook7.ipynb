# %%
import urllib.request
url = "https://www.uniprot.org/docs/humchrx.txt"
destination_filename = '../Data/humstr1.txt'
urllib.request.urlretrieve (url , destination_filename)
# Out:
# ('../Data/humstr1.txt', <http.client.HTTPMessage at 0x7ff43c38f080>)

# %%
humchr= open('../Data/humchrx.txt','r')
line = humchr.readline()
print(line)
humchr.close()
# Out:
# ----------------------------------------------------------------------------

# %%
names = ['joe','zoe','brad','angela','bole']
for name in names:
    invite = 'Hi %s. please' %name
    print(invite)
# Out:
# Hi joe. please
# Hi zoe. please
# Hi brad. please
# Hi angela. please
# Hi bole. please

# %%
def gene_extr(filename):
    abc = 'humchrx.txt'
    with open('../Data/humchrx.txt','r') as myfile:
            lines = myfile.readlines()
            for line in lines:
                print(line)
                return (lines)

# %%
gene_extractor()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-070f906a52df> in <module>()
# ----> 1 gene_extractor(test.txt)
#
# NameError: name 'test' is not defined

# %%
with open('../Data/humchrx.txt','r') as myfile:
    while True:
        lines = myfile.readline()
        if len(lines) == 0:
            break
        print(lines)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-bef56a18c27d> in <module>()
#       4         if len(lines) == 0:
#       5             break
# ----> 6         print(lies)
#       7
#
# NameError: name 'lies' is not defined

# %%
gene_extra('../Data/humchrx.txt')
# Out:
# []

# %%
###Extracts species from a file
species=[]
def gene_extra('../Data/humchrx.txt'):
    with open('../Data/humchrx.txt','r') as myfile:
        lines = myfile.readlines()
        for i,line in enumerate(lines):
            if i>35:
                line_split = line.split()
                fields = (line_split[0])
                if fields.startswith('-'):
                    break
                #print(fields)
                joined=''.join(fields)
                species.append(joined)
    return(species)
    #print(species)
# Out:
#   File "<ipython-input-8-bd8feb1c2175>", line 3
#     def gene_extra('../Data/humchrx.txt'):
#                                        ^
# SyntaxError: invalid syntax

# %%
def gene_writer('../Data/species.txt'):
    with open('../Data/species.txt','w')as outfile:
        outfile.write('species\n')
        for sp in species:
            outfile.write(sp+'\n')
    return()

# %%
gene_extra('../Data/humstr1.txt')
# Out:
# ['ABCB7',
#  'ABCD1',
#  'ACE2',
#  'ACOT9',
#  'ACSL4',
#  'ACTRT1',
#  'ADGRG2',
#  'ADGRG4',
#  'AFF2',
#  'AGTR2',
#  'AIFM1',
#  'AKAP14',
#  'AKAP17A',
#  'AKAP4',
#  'ALAS2',
#  'ALG13',
#  'AMELX',
#  'AMER1',
#  'AMMECR1',
#  'AMOT',
#  'ANOS1',
#  'AP1S2',
#  'APEX2',
#  'APLN',
#  'APOO',
#  'APOOL',
#  'AR',
#  'ARAF',
#  'ARHGAP36',
#  'ARHGAP4',
#  'ARHGAP6',
#  'ARHGEF6',
#  'ARHGEF9',
#  'ARL13A',
#  'ARMCX1',
#  'ARMCX2',
#  'ARMCX3',
#  'ARMCX4',
#  'ARMCX5',
#  'ARMCX6',
#  'ARR3',
#  'ARSD',
#  'ARSF',
#  'ARSH',
#  'ARSL',
#  'ARX',
#  'ASB11',
#  'ASB12',
#  'ASB9',
#  'ASMT',
#  'ASMTL',
#  'ATG4A',
#  'ATP11C',
#  'ATP1B4',
#  'ATP2B3',
#  'ATP6AP1',
#  'ATP6AP2',
#  'ATP7A',
#  'ATRX',
#  'ATXN3L',
#  'AVPR2',
#  'AWAT1',
#  'AWAT2',
#  'BCAP31',
#  'BCLAF3',
#  'BCOR',
#  'BCORL1',
#  'BEND2',
#  'BEX1',
#  'BEX2',
#  'BEX3',
#  'BEX4',
#  'BEX5',
#  'BGN',
#  'BHLHB9',
#  'BMP15',
#  'BMP2KL',
#  'BMX',
#  'BRCC3',
#  'BRS3',
#  'BRWD3',
#  'BTK',
# ...

# %%
#combined function
# This first code extracts all the species from files that have the species at fields 0
species=[]
def gene_extra(filename):
    with open('../Data/humchrx.txt','r') as myfile:
        lines = myfile.readlines()
        for i,line in enumerate(lines):
            if i>35:
                line_split = line.split()
                fields = (line_split[0])
                if fields.startswith('-'):
                    break
                #print(fields)
                joined=''.join(fields)
                species.append(joined)
                
return(species)

#this second code writes the species extracted from the first code to a file
def gene_writer(speciesfile):
    with open('../Data/species.txt','w')as outfile:
        outfile.write('species\n')
        for sp in species:
            outfile.write(sp+'\n')
             return(speciesfile)
# Out:
#   File "<ipython-input-17-6b4ad2242939>", line 25
#     return(speciesfile)
#     ^
# IndentationError: unexpected indent

# %%
###Extracts species from a file
def gene_extra(inputfile,outfile):
    with open(inputfile,'r') as myfile:
        with open(outfile,'w') as outfile:
            lines = myfile.readlines()
            for i,line in enumerate(lines):
                if i>35:
                    line_split = line.split()
                    fields = (line_split[0])
                    if fields.startswith('-'):
                        break
                    #print(fields)
                    joined=''.join(fields)
                    
                    outfile.write(joined +'\n')
   
    #print(species)

# %%
gene_extra('../Data/humstr1.txt',"../Data/genenames.txt")
